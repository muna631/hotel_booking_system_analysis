# %% [markdown]
# # import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # loading dataset

# %%
df = pd.read_csv('hotel_bookings 2.csv')

# %% [markdown]
# # exploratory data analysis and data cleaning

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail()
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 76522  City Hotel            1        195               2015
# 76523  City Hotel            1        195               2015
# 76524  City Hotel            1        195               2015
# 76525  City Hotel            1        195               2015
# 76526  City Hotel            1        195               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 76522          September                        38                         17
# 76523          September                        38                         17
# 76524          September                        38                         17
# 76525          September                        38                         17
# 76526          September                        38                         17
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
df.shape
# Out:
# (76527, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76527 entries, 0 to 76526
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           76527 non-null  object
#  1   is_canceled                     76527 non-null  int64
#  2   lead_time                       76527 non-null  int64
#  3   arrival_date_year               76527 non-null  int64
#  4   arrival_date_month              76527 non-null  object
#  5   arrival_date_week_number        76527 non-null  int64
#  6   arrival_date_day_of_month       76527 non-null  int64
#  7   stays_in_weekend_nights         76527 non-null  int64
#  8   stays_in_week_nights            76527 non-null  int64
#  9   adults                          76527 non-null  int64
#  10  children                        76523 non-null  float64
#  11  babies                          76527 non-null  int64
# ...

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76527 entries, 0 to 76526
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   hotel                           76527 non-null  object
#  1   is_canceled                     76527 non-null  int64
#  2   lead_time                       76527 non-null  int64
#  3   arrival_date_year               76527 non-null  int64
#  4   arrival_date_month              76527 non-null  object
#  5   arrival_date_week_number        76527 non-null  int64
#  6   arrival_date_day_of_month       76527 non-null  int64
#  7   stays_in_weekend_nights         76527 non-null  int64
#  8   stays_in_week_nights            76527 non-null  int64
#  9   adults                          76527 non-null  int64
#  10  children                        76523 non-null  float64
#  11  babies                          76527 non-null  int64
# ...

# %%
df.describe(include = 'object')
# Out:
#                hotel arrival_date_month   meal country market_segment  \
# count          76527              76527  76527   76041          76527
# unique             2                 12      5     151              8
# top     Resort Hotel             August     BB     PRT      Online TA
# freq           40060               9582  59077   37431          34133
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                 76527              76527              76527
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  63041              53501              45618
#
#        deposit_type customer_type reservation_status
# count         76527         76527              76527
# unique            3             4                  3
# top      No Deposit     Transient           Canceled
# freq          63428         57357              40502

# %%
for cl in df.describe(include = 'object').columns:
    print(cl)
    print(df[cl].unique())
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             486
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
df.drop(['company', 'agent'], axis = 'columns', inplace = True)
df.dropna(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.drop(['company', 'agent'], axis = 'columns', inplace = True)
#       2 df.dropna(inplace = True)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  76037.000000  76037.000000       76037.000000
# mean       0.546339    116.782619        2016.097531
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     25.000000        2016.000000
# 50%        1.000000     83.000000        2016.000000
# 75%        1.000000    178.000000        2017.000000
# max        1.000000    737.000000        2017.000000
# std        0.497851    112.515333           0.737467
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              76037.000000               76037.000000
# mean                  27.464918                  15.730105
# min                    1.000000                   1.000000
# 25%                   17.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
# ...

# %%
df= df[df['adr']<5000]

# %%
df['adr'].plot  (kind = 'box')
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  76036.000000  76036.000000       76036.000000
# mean       0.546333    116.783695        2016.097533
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     25.000000        2016.000000
# 50%        1.000000     83.000000        2016.000000
# 75%        1.000000    178.000000        2017.000000
# max        1.000000    737.000000        2017.000000
# std        0.497852    112.515682           0.737471
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              76036.000000               76036.000000
# mean                  27.465109                  15.729983
# min                    1.000000                   1.000000
# 25%                   17.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# max                   53.000000                  31.000000
# ...

# %% [markdown]
# # data analysis and visualization

# %%
cancel_percentage = df['is_canceled'].value_counts(normalize= True)
print(cancel_percentage)
# Out:
# is_canceled
# 1    0.546333
# 0    0.453667
# Name: proportion, dtype: float64

# %%
cancel_percentage = df['is_canceled'].value_counts(normalize= True)
print(cancel_percentage)

plt.figure(figsize=(5,4))
plt.title('reservation status count')
plt.bar(['not cancelled','cancelled'],df['is_canceled'].value_counts(), edgecolor = 'k', width = 0.7)
plt.show()
# Out:
# is_canceled
# 1    0.546333
# 0    0.453667
# Name: proportion, dtype: float64

# %% [markdown]
# # analysis different catagories for cancellization

# %%
plt.figure(figsize = (8,4))
plt.title('reservation status in different hotel', size = 15)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
ax1 = sns.countplot(x = 'hotel', hue = 'is_canceled', data = df, palette = 'cividis')

# %%
resort_hotel = df[df['hotel'] == 'Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 0    0.72025
# 1    0.27975
# Name: proportion, dtype: float64

# %%
city_hotel = df[df['hotel'] == 'City Hotel']
city_hotel['is_canceled'].value_counts(normalize = True)
# Out:
# is_canceled
# 1    0.836004
# 0    0.163996
# Name: proportion, dtype: float64

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize = (20,8))
plt.title('Average daily rate in city and resort hotel')
plt.plot(resort_hotel.index,resort_hotel['adr'], label = 'resort_hotel')
plt.plot(city_hotel.index,city_hotel['adr'], label = 'city_hotel')
plt.legend()
plt.show()

# %%
df['month'] = df['reservation_status_date'].dt.month
plt.figure(figsize = (18,8))
ax1 = sns.countplot(x = 'month', hue = 'is_canceled', data = df, palette = 'bright')
plt.title('Reservation status per month')
plt.xlabel('month')
plt.ylabel('number of reservations')
plt.show()
